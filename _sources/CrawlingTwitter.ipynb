# %% [markdown]
# # CRAWLING TWITTER USING SNSCRAPE

# %% [markdown]
# ## 1. Install Modul SNSCRAPE

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.26.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %% [markdown]
# ## 2. Import Library SNSCRAPE

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# ## 3. Crawling data twitter dengan SNSCRAPE

# %%
#Insialisai variable list untuk hasil crawling
list_data = []

#Membuat perulangan untuk melakukan crawling menggunakan snscraper dan di masukkan kedalam list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('ridwankamil').get_items()):
    list_data.append([tweet.date, tweet.content, tweet.user. username, tweet.user.location])
    if i>500:
        break
# Out:
# <ipython-input-5-097c1f6e472d>:6: FutureWarning: content is deprecated, use rawContent instead
#   list_data.append([tweet.date, tweet.content, tweet.user. username, tweet.user.location])

# %% [markdown]
# * DataFrame hasil crawling twitter

# %%
#Membuat dataframe hasil crawlingmel 
df = pd.DataFrame(list_data, columns=['Datetime', 'Text', 'Username', 'Lokasi'])

df
# Out:
#                      Datetime  \
# 0   2023-03-02 15:48:12+00:00
# 1   2023-03-02 15:46:07+00:00
# 2   2023-03-02 15:43:30+00:00
# 3   2023-03-02 15:42:51+00:00
# 4   2023-03-02 15:39:53+00:00
# ..                        ...
# 497 2023-03-02 02:49:12+00:00
# 498 2023-03-02 02:48:39+00:00
# 499 2023-03-02 02:48:29+00:00
# 500 2023-03-02 02:48:16+00:00
# 501 2023-03-02 02:47:49+00:00
#
#                                                   Text         Username  \
# 0    @humasjabar @ridwankamil @ESDMJabar HAHAHAHAHA...     gunanyaindra
# 1    @sastrajawacom Cc @jokowi \n@ganjarpranowo \n@...      anjar_kz200
# 2    @humasjabar @ridwankamil @ESDMJabar Beraaaak s...         bluuvlvt
# 3    @PaUuRuzhanul @ridwankamil @humasjabar Emang p...         thauvikh
# 4    @sangkuriang1966 @haloriungbdg @PRFMnews @Info...           nyao96
# ..                                                 ...              ...
# 497  @humasjabar @ridwankamil @ESDMJabar https://t....         Qodridio
# 498  @rizkirinardi @kangyanamulyana @ridwankamil Ku...  anggaprayogie99
# 499      @convomf @ridwankamil pak tolong di bantu yah          habibhf
# 500  @anggaprayogie99 @kangyanamulyana @ridwankamil...     rizkirinardi
# 501  @Outstandjing @ridwankamil Ntar dijawabnya, "g...   angga_ramdhana
#
#                             Lokasi
# 0
# 1                        Indonesia
# 2
# 3
# 4
# ..                             ...
# 497                     yogyakarta
# 498  ibu kota korsel mantap seoul👌
# 499                        bandung
# 500
# 501           Tangerang, Indonesia
#
# [502 rows x 4 columns]

# %% [markdown]
# ## 4.Export To CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/prosaindata/ridwankamil.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df.to_csv(f)
# Out:
# Mounted at /content/drive
